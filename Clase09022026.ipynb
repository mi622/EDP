# %% [markdown]
# <a href="https://colab.research.google.com/github/mi622/EDP/blob/main/Clase09022026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tabulate

# %%
def generador(a,b,m,x):
  x1=(a*x0+b)  %m
  return x1

# %%
n=70
a=9
b=9
m=64
x0=1
muestra=[]
datos=[]

for i in range(n):
     nuevo=generador(a,b,m,x0)
     muestra.append([i,x0,nuevo/64])
     datos.append(x0/64)
     x0=nuevo


     encabezados=["","x_","X_{i+1}"]
     print(tabulate.tabulate(muestra, headers=encabezados, tablefmt="psql",numalign="cente"))
# Out:
# +----+------+-----------+
# |    |   x_ |   X_{i+1} |
# |----+------+-----------|
# | 0  | 1    | 0.28125   |
# +----+------+-----------+
# +----+------+-----------+
# |    |   x_ |   X_{i+1} |
# |----+------+-----------|
# | 0  | 1    | 0.28125   |
# | 1  | 18   | 0.671875  |
# +----+------+-----------+
# +----+------+-----------+
# |    |   x_ |   X_{i+1} |
# |----+------+-----------|
# | 0  | 1    | 0.28125   |
# | 1  | 18   | 0.671875  |
# | 2  | 43   | 0.1875    |
# +----+------+-----------+
# +----+------+-----------+
# |    |   x_ |   X_{i+1} |
# |----+------+-----------|
# | 0  | 1    | 0.28125   |
# | 1  | 18   | 0.671875  |
# | 2  | 43   | 0.1875    |
# | 3  | 12   | 0.828125  |
# +----+------+-----------+
# +----+------+-----------+
# |    |   x_ |   X_{i+1} |
# |----+------+-----------|
# | 0  | 1    | 0.28125   |
# | 1  | 18   | 0.671875  |
# | 2  | 43   | 0.1875    |
# | 3  | 12   | 0.828125  |
# | 4  | 53   | 0.59375   |
# +----+------+-----------+
# ...
